# %%
# %pip install cohere pinecone datasets python-dotenv
# Out:
# The kernel failed to start as the Python Environment 'Python 3.12.3' is no longer available. Consider selecting another kernel or refreshing the list of Python Environments.

# %%
# %pip install --upgrade cohere pinecone-client datasets python-dotenv
# Out:
# The kernel failed to start as the Python Environment 'Python 3.12.3' is no longer available. Consider selecting another kernel or refreshing the list of Python Environments.
